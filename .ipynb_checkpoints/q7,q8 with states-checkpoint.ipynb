# %% [markdown]
# 7) From the housing data(Data/housing.csv) read the following columns which may be relevant to the requirement.
# District Name
# Rural/Urban
# Total Number of households
# Total Number of Livable
# Total Number of Dilapidated
# Latrine_premise

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings

# %%
housing=pd.read_csv('Data/housing.csv',usecols=['State Name','District Name','Rural/Urban','Total Number of households','Total Number of Livable','Total Number of Dilapidated','Latrine_premise'])

# %% [markdown]
# #seperating urban and rural so that we can create a concatenated table for rural and urban only

# %%
housing.set_index(['Rural/Urban'],inplace=True)

# %%
rural=housing.loc['Rural'].copy()

# %%
urban=housing.loc['Urban'].copy()
urban.reset_index(drop=True, inplace=True)

# %%
rural.reset_index(drop=True, inplace=True)

# %%
combined=rural.merge(urban,how='inner',on="District Name",suffixes=('_rural','_urban'))

# %%
combined
# Out:
#               State Name_rural            District Name  \
# 0              JAMMU & KASHMIR                  Kupwara
# 1              JAMMU & KASHMIR                   Badgam
# 2              JAMMU & KASHMIR              Leh(Ladakh)
# 3              JAMMU & KASHMIR                   Kargil
# 4              JAMMU & KASHMIR                    Punch
# ..                         ...                      ...
# 635                 TAMIL NADU                 Tiruppur
# 636                 PUDUCHERRY               Puducherry
# 637                 PUDUCHERRY                 Karaikal
# 638  ANDAMAN & NICOBAR ISLANDS  North  & Middle Andaman
# 639  ANDAMAN & NICOBAR ISLANDS            South Andaman
#
#      Total Number of households_rural  Total Number of Livable_rural  \
# 0                                 100                           58.1
# 1                                 100                           46.3
# 2                                 100                           51.5
# 3                                 100                           73.3
# 4                                 100                           59.5
# ..                                ...                            ...
# 635                               100                           27.6
# 636                               100                           31.9
# 637                               100                           36.8
# 638                               100                           44.3
# 639                               100                           33.5
#
#      Total Number of Dilapidated_rural  Latrine_premise_rural  \
# 0                                  8.3                   48.9
# 1                                  3.9                   83.3
# 2                                  2.1                   88.1
# 3                                  3.5                   96.8
# 4                                  2.4                   13.7
# ..                                 ...                    ...
# 635                                1.7                   30.9
# 636                                2.6                   35.8
# 637                                2.1                   47.6
# 638                                2.7                   48.0
# 639                                3.5                   64.7
#
#               State Name_urban  Total Number of households_urban  \
# 0              JAMMU & KASHMIR                               100
# 1              JAMMU & KASHMIR                               100
# 2              JAMMU & KASHMIR                               100
# 3              JAMMU & KASHMIR                               100
# 4              JAMMU & KASHMIR                               100
# ..                         ...                               ...
# 635                 TAMIL NADU                               100
# 636                 PUDUCHERRY                               100
# 637                 PUDUCHERRY                               100
# 638  ANDAMAN & NICOBAR ISLANDS                               100
# 639  ANDAMAN & NICOBAR ISLANDS                               100
#
#      Total Number of Livable_urban  Total Number of Dilapidated_urban  \
# 0                             49.5                                4.8
# 1                             33.8                                2.6
# 2                             54.6                                1.1
# 3                             68.8                                1.2
# 4                             27.3                                0.8
# ..                             ...                                ...
# 635                           23.6                                0.7
# 636                           19.0                                1.2
# 637                           21.0                                1.2
# 638                           55.9                                6.6
# 639                           21.4                                1.2
#
#      Latrine_premise_urban
# 0                     70.2
# 1                     90.4
# 2                     95.8
# 3                     97.5
# 4                     75.3
# ..                     ...
# 635                   75.0
# 636                   82.5
# 637                   74.4
# 638                   56.1
# 639                   87.8
#
# [640 rows x 11 columns]

# %%
combined.columns=['State/UT_rural','District','Households_Rural','Households_Rural_Livable','Households_Rural_Dilapidated','Households_Rural_Toilet_Premise','State/UT_urban','Households_Urban','Households_Urban_Livable','Households_Urban_Dilapidated','Households_Urban_Toilet_Premise']

# %%
combined['State/UT_rural']=combined['State/UT_rural'].str.title()

# %%
combined['State/UT_urban']=combined['State/UT_urban'].str.title()

# %%
combined.drop('State/UT_urban',axis=1,inplace=True)

# %%
combined
# Out:
#                 State/UT_rural                 District  Households_Rural  \
# 0              Jammu & Kashmir                  Kupwara               100
# 1              Jammu & Kashmir                   Badgam               100
# 2              Jammu & Kashmir              Leh(Ladakh)               100
# 3              Jammu & Kashmir                   Kargil               100
# 4              Jammu & Kashmir                    Punch               100
# ..                         ...                      ...               ...
# 635                 Tamil Nadu                 Tiruppur               100
# 636                 Puducherry               Puducherry               100
# 637                 Puducherry                 Karaikal               100
# 638  Andaman & Nicobar Islands  North  & Middle Andaman               100
# 639  Andaman & Nicobar Islands            South Andaman               100
#
#      Households_Rural_Livable  Households_Rural_Dilapidated  \
# 0                        58.1                           8.3
# 1                        46.3                           3.9
# 2                        51.5                           2.1
# 3                        73.3                           3.5
# 4                        59.5                           2.4
# ..                        ...                           ...
# 635                      27.6                           1.7
# 636                      31.9                           2.6
# 637                      36.8                           2.1
# 638                      44.3                           2.7
# 639                      33.5                           3.5
#
#      Households_Rural_Toilet_Premise  Households_Urban  \
# 0                               48.9               100
# 1                               83.3               100
# 2                               88.1               100
# 3                               96.8               100
# 4                               13.7               100
# ..                               ...               ...
# 635                             30.9               100
# 636                             35.8               100
# 637                             47.6               100
# 638                             48.0               100
# 639                             64.7               100
#
#      Households_Urban_Livable  Households_Urban_Dilapidated  \
# 0                        49.5                           4.8
# 1                        33.8                           2.6
# 2                        54.6                           1.1
# 3                        68.8                           1.2
# 4                        27.3                           0.8
# ..                        ...                           ...
# 635                      23.6                           0.7
# 636                      19.0                           1.2
# 637                      21.0                           1.2
# 638                      55.9                           6.6
# 639                      21.4                           1.2
#
#      Households_Urban_Toilet_Premise
# 0                               70.2
# 1                               90.4
# 2                               95.8
# 3                               97.5
# 4                               75.3
# ..                               ...
# 635                             75.0
# 636                             82.5
# 637                             74.4
# 638                             56.1
# 639                             87.8
#
# [640 rows x 10 columns]

# %%
combined.columns=['State/UT','District','Households_Rural','Households_Rural_Livable','Households_Rural_Dilapidated','Households_Rural_Toilet_Premise','Households_Urban','Households_Urban_Livable','Households_Urban_Dilapidated','Households_Urban_Toilet_Premise']

# %%
combined['State/UT']=combined['State/UT'].str.replace("&","and")

# %% [markdown]
# now read the census cleaned data from pb7

# %%
housing=pd.read_csv('Data/census_clean.csv',usecols=['Households_Rural','Households_Urban','Households','District','State/UT'])

# %%
housing.head()
# Out:
#             State/UT     District  Households_Rural  Households_Urban  \
# 0  Jammu and Kashmir      Kupwara          158438.0           23226.0
# 1  Jammu and Kashmir       Badgam          160649.0           27190.0
# 2            Laddakh  Leh(Ladakh)           36920.0           17474.0
# 3            Laddakh       Kargil           40370.0            7774.0
# 4  Jammu and Kashmir        Punch          132139.0           15269.0
#
#    Households
# 0    181664.0
# 1    187839.0
# 2     54394.0
# 3     48144.0
# 4    147408.0

# %%
housing['Households_Rural_Livable']=housing['Households_Rural']*(combined['Households_Rural_Livable']/100)

# %%
housing['Households_Rural_Dilapidated']=housing['Households_Rural']*(combined['Households_Rural_Dilapidated']/100)

# %%
housing['Households_Rural_Toilet_Premise']=housing['Households_Rural']*(combined['Households_Rural_Toilet_Premise']/100)

# %%
housing['Households_Urban_Livable']=housing['Households_Urban']*(combined['Households_Urban_Livable']/100)

# %%
housing['Households_Urban_Dilapidated']=housing['Households_Urban']*(combined['Households_Urban_Dilapidated']/100)

# %%
housing['Households_Urban_Toilet_Premise']=housing['Households_Urban']*(combined['Households_Urban_Toilet_Premise']/100)

# %%
housing
# Out:
#                         State/UT                   District  Households_Rural  \
# 0              Jammu and Kashmir                    Kupwara          158438.0
# 1              Jammu and Kashmir                     Badgam          160649.0
# 2                        Laddakh                Leh(Ladakh)           36920.0
# 3                        Laddakh                     Kargil           40370.0
# 4              Jammu and Kashmir                      Punch          132139.0
# ..                           ...                        ...               ...
# 635                  Pondicherry                       Mahe               0.0
# 636                  Pondicherry                   Karaikal           35618.0
# 637  Andaman and Nicobar Islands                   Nicobars           15958.0
# 638  Andaman and Nicobar Islands  North  AND Middle Andaman           39091.0
# 639  Andaman and Nicobar Islands              South Andaman           34901.0
#
#      Households_Urban  Households  Households_Rural_Livable  \
# 0             23226.0    181664.0                 92052.478
# 1             27190.0    187839.0                 74380.487
# 2             17474.0     54394.0                 19013.800
# 3              7774.0     48144.0                 29591.210
# 4             15269.0    147408.0                 78622.705
# ..                ...         ...                       ...
# 635           12110.0     12110.0                     0.000
# 636           33715.0     69333.0                 11362.142
# 637               0.0     15958.0                  5872.544
# 638            1094.0     40185.0                 17317.313
# 639           50631.0     85532.0                 11691.835
#
#      Households_Rural_Dilapidated  Households_Rural_Toilet_Premise  \
# 0                       13150.354                        77476.182
# 1                        6265.311                       133820.617
# 2                         775.320                        32526.520
# 3                        1412.950                        39078.160
# 4                        3171.336                        18103.043
# ..                            ...                              ...
# 635                         0.000                            0.000
# 636                       926.068                        12751.244
# 637                       335.118                         7596.008
# 638                      1055.457                        18763.680
# 639                      1221.535                        22580.947
#
#      Households_Urban_Livable  Households_Urban_Dilapidated  \
# 0                   11496.870                      1114.848
# 1                    9190.220                       706.940
# 2                    9540.804                       192.214
# 3                    5348.512                        93.288
# 4                    4168.437                       122.152
# ..                        ...                           ...
# 635                  2857.960                        84.770
# 636                  6405.850                       404.580
# 637                     0.000                         0.000
# 638                   611.546                        72.204
# 639                 10835.034                       607.572
#
#      Households_Urban_Toilet_Premise
# 0                          16304.652
# 1                          24579.760
# 2                          16740.092
# 3                           7579.650
# 4                          11497.557
# ..                               ...
# 635                         9082.500
# 636                        27814.875
# 637                            0.000
# 638                          613.734
# 639                        44454.018
#
# [640 rows x 11 columns]

# %%
housing = housing.reindex(sorted(housing.columns), axis=1)

# %%
#housing.drop('Households',axis=1,inplace=True)

# %%
housing
# Out:
#                       District  Households  Households_Rural  \
# 0                      Kupwara    181664.0          158438.0
# 1                       Badgam    187839.0          160649.0
# 2                  Leh(Ladakh)     54394.0           36920.0
# 3                       Kargil     48144.0           40370.0
# 4                        Punch    147408.0          132139.0
# ..                         ...         ...               ...
# 635                       Mahe     12110.0               0.0
# 636                   Karaikal     69333.0           35618.0
# 637                   Nicobars     15958.0           15958.0
# 638  North  AND Middle Andaman     40185.0           39091.0
# 639              South Andaman     85532.0           34901.0
#
#      Households_Rural_Dilapidated  Households_Rural_Livable  \
# 0                       13150.354                 92052.478
# 1                        6265.311                 74380.487
# 2                         775.320                 19013.800
# 3                        1412.950                 29591.210
# 4                        3171.336                 78622.705
# ..                            ...                       ...
# 635                         0.000                     0.000
# 636                       926.068                 11362.142
# 637                       335.118                  5872.544
# 638                      1055.457                 17317.313
# 639                      1221.535                 11691.835
#
#      Households_Rural_Toilet_Premise  Households_Urban  \
# 0                          77476.182           23226.0
# 1                         133820.617           27190.0
# 2                          32526.520           17474.0
# 3                          39078.160            7774.0
# 4                          18103.043           15269.0
# ..                               ...               ...
# 635                            0.000           12110.0
# 636                        12751.244           33715.0
# 637                         7596.008               0.0
# 638                        18763.680            1094.0
# 639                        22580.947           50631.0
#
#      Households_Urban_Dilapidated  Households_Urban_Livable  \
# 0                        1114.848                 11496.870
# 1                         706.940                  9190.220
# 2                         192.214                  9540.804
# 3                          93.288                  5348.512
# 4                         122.152                  4168.437
# ..                            ...                       ...
# 635                        84.770                  2857.960
# 636                       404.580                  6405.850
# 637                         0.000                     0.000
# 638                        72.204                   611.546
# 639                       607.572                 10835.034
#
#      Households_Urban_Toilet_Premise                     State/UT
# 0                          16304.652            Jammu and Kashmir
# 1                          24579.760            Jammu and Kashmir
# 2                          16740.092                      Laddakh
# 3                           7579.650                      Laddakh
# 4                          11497.557            Jammu and Kashmir
# ..                               ...                          ...
# 635                         9082.500                  Pondicherry
# 636                        27814.875                  Pondicherry
# 637                            0.000  Andaman and Nicobar Islands
# 638                          613.734  Andaman and Nicobar Islands
# 639                        44454.018  Andaman and Nicobar Islands
#
# [640 rows x 11 columns]

# %% [markdown]
# Convert it into csv

# %%
housing.to_csv('clean_Data/Clean_Data/housing_cleanwithStates.csv', index=False)

# %% [markdown]
# Now we have to find the columns that are missing in both census and housing

# %%
housing
# Out:
#                       District  Households  Households_Rural  \
# 0                      Kupwara    181664.0          158438.0
# 1                       Badgam    187839.0          160649.0
# 2                  Leh(Ladakh)     54394.0           36920.0
# 3                       Kargil     48144.0           40370.0
# 4                        Punch    147408.0          132139.0
# ..                         ...         ...               ...
# 635                       Mahe     12110.0               0.0
# 636                   Karaikal     69333.0           35618.0
# 637                   Nicobars     15958.0           15958.0
# 638  North  AND Middle Andaman     40185.0           39091.0
# 639              South Andaman     85532.0           34901.0
#
#      Households_Rural_Dilapidated  Households_Rural_Livable  \
# 0                       13150.354                 92052.478
# 1                        6265.311                 74380.487
# 2                         775.320                 19013.800
# 3                        1412.950                 29591.210
# 4                        3171.336                 78622.705
# ..                            ...                       ...
# 635                         0.000                     0.000
# 636                       926.068                 11362.142
# 637                       335.118                  5872.544
# 638                      1055.457                 17317.313
# 639                      1221.535                 11691.835
#
#      Households_Rural_Toilet_Premise  Households_Urban  \
# 0                          77476.182           23226.0
# 1                         133820.617           27190.0
# 2                          32526.520           17474.0
# 3                          39078.160            7774.0
# 4                          18103.043           15269.0
# ..                               ...               ...
# 635                            0.000           12110.0
# 636                        12751.244           33715.0
# 637                         7596.008               0.0
# 638                        18763.680            1094.0
# 639                        22580.947           50631.0
#
#      Households_Urban_Dilapidated  Households_Urban_Livable  \
# 0                        1114.848                 11496.870
# 1                         706.940                  9190.220
# 2                         192.214                  9540.804
# 3                          93.288                  5348.512
# 4                         122.152                  4168.437
# ..                            ...                       ...
# 635                        84.770                  2857.960
# 636                       404.580                  6405.850
# 637                         0.000                     0.000
# 638                        72.204                   611.546
# 639                       607.572                 10835.034
#
#      Households_Urban_Toilet_Premise                     State/UT
# 0                          16304.652            Jammu and Kashmir
# 1                          24579.760            Jammu and Kashmir
# 2                          16740.092                      Laddakh
# 3                           7579.650                      Laddakh
# 4                          11497.557            Jammu and Kashmir
# ..                               ...                          ...
# 635                         9082.500                  Pondicherry
# 636                        27814.875                  Pondicherry
# 637                            0.000  Andaman and Nicobar Islands
# 638                          613.734  Andaman and Nicobar Islands
# 639                        44454.018  Andaman and Nicobar Islands
#
# [640 rows x 11 columns]

# %%
districts=combined['District'].tolist()

# %%
unmatched=housing[~housing['District'].isin(districts)]['District']

# %%
unmatched
# Out:
# 24               Lahul AND Spiti
# 33                       Kinnaur
# 93                     New Delhi
# 94                       Central
# 341                      Kolkata
# 495       Dadra AND Nagar Haveli
# 517              Mumbai Suburban
# 518                       Mumbai
# 535                    Hyderabad
# 586                  Lakshadweep
# 602                      Chennai
# 633                        Yanam
# 634                  PONDICHERRY
# 635                         Mahe
# 637                     Nicobars
# 638    North  AND Middle Andaman
# Name: District, dtype: object

# %%
census=pd.read_csv('clean_Data/census_clean.csv')

# %%
districts=census['District'].tolist()

# %%
housing['District']=housing['District'].str.title()

# %%
def func(word):
    word=word.title()
    word=word.replace(' And ',' and ')
    return word

# %%
housing['District']=housing['District'].apply(func)

# %%
unmatched=housing[~housing['District'].isin(districts)]['District']

# %%
unmatched
# Out:
# 24               Lahul and Spiti
# 495       Dadra and Nagar Haveli
# 634                  Pondicherry
# 638    North  and Middle Andaman
# Name: District, dtype: object

# %% [markdown]
# Problem Statement 8: (Visualise the housing data)

# %% [markdown]
# Visualize the following data for each state using appropriate methods:
# Number of households for 100 people
# Percentage of households that have toilet(s) in premise to the total number of households.
# Urban to rural population ratio.

# %%
a=housing["Households_Rural_Toilet_Premise"].sum()+housing["Households_Urban_Toilet_Premise"].sum()

# %%
b=housing["Households_Rural"].sum()+housing["Households_Urban"].sum()

# %%
a
# Out:
# 156642353.56165802

# %%
b
# Out:
# 330951688.6084

# %%
(a/b)*100
# Out:
# 47.330882105576976

# %%
data7 = {'value': [a,b]}
chart = pd.DataFrame(data7, index=['Having', 'Total households'])

# Calculate the percentage of each value
total = chart['value'].sum()
chart['percent'] = chart['value'] / total * 100

colors = ['#FFE0AC', '#FFACB7']
fig, ax = plt.subplots(figsize=(8, 6))
# Create a pie chart of the percentages
chart['percent'].plot(kind='pie', colors=colors, autopct='%1.1f%%', startangle=90, pctdistance=0.8, wedgeprops={'linewidth': 1, 'edgecolor': 'white'})
plt.axis('equal')
plt.legend(labels=chart.index, loc='upper left')
plt.title('  Percentage of households that have toilet(s) in premise to the total number of households.')

plt.legend(labels=chart.index, loc='upper right', bbox_to_anchor=(1.2, 1))
plt.tight_layout()
plt.ylabel('')

# Save the chart to a file
plt.savefig('toilet_pie_chart.png')

plt.show()

# %%
df_population = housing[['Households_Urban', 'Households_Rural']]

# %%
ax = df_population.plot.bar(rot=0,color=colors)
ax.set_xlabel('Population')
ax.set_ylabel('Number of People')
ax.set_title('Comparison of Urban and Rural Populations')
# Out:
# Text(0.5, 1.0, 'Comparison of Urban and Rural Populations')

# %%
census=pd.read_csv('clean_Data/Clean_Data/clean_census.csv')

# %%
census
# Out:
#      Unnamed: 0                     State/UT                   District  \
# 0             0            Jammu and Kashmir                    Kupwara
# 1             1            Jammu and Kashmir                     Badgam
# 2             2                      Laddakh                Leh(Ladakh)
# 3             3                      Laddakh                     Kargil
# 4             4            Jammu and Kashmir                      Punch
# ..          ...                          ...                        ...
# 635         635                  Pondicherry                       Mahe
# 636         636                  Pondicherry                   Karaikal
# 637         637  Andaman and Nicobar Islands                   Nicobars
# 638         638  Andaman and Nicobar Islands  North  and Middle Andaman
# 639         639  Andaman and Nicobar Islands              South Andaman
#
#      Population      Male    Female  Literate  Literate_Male  Literate_Female  \
# 0      870354.0  474190.0  396164.0  439654.0       282823.0         156831.0
# 1      753745.0  398041.0  355704.0  335649.0       207741.0         127908.0
# 2      133487.0   78971.0   54516.0   93770.0        62834.0          30936.0
# 3      140802.0   77785.0   63017.0   86236.0        56301.0          29935.0
# 4      476835.0  251899.0  224936.0  261724.0       163333.0          98391.0
# ..          ...       ...       ...       ...            ...              ...
# 635     41816.0   19143.0   22673.0   36470.0        16610.0          19860.0
# 636    200222.0   97809.0  102413.0  154916.0        79903.0          75013.0
# 637     36842.0   20727.0   16115.0   25332.0        15397.0           9935.0
# 638    105597.0   54861.0   50736.0   78683.0        43186.0          35497.0
# 639    238142.0  127283.0  110859.0  190266.0       105794.0          84472.0
#
#      Households_Rural  Households_Urban  Households  Young_and_Adult  \
# 0            158438.0           23226.0    181664.0     6.007590e+05
# 1            160649.0           27190.0    187839.0     5.032230e+05
# 2             36920.0           17474.0     54394.0     7.070300e+04
# 3             40370.0            7774.0     48144.0     8.753200e+04
# 4            132139.0           15269.0    147408.0     3.049790e+05
# ..                ...               ...         ...              ...
# 635               0.0           12110.0     12110.0     1.976000e+04
# 636           35618.0           33715.0     69333.0     1.107321e+06
# 637           15958.0               0.0     15958.0     1.878600e+04
# 638           39091.0            1094.0     40185.0     5.735000e+04
# 639           34901.0           50631.0     85532.0     1.284020e+05
#
#      Middle_Aged  Senior_Citizen  Age_Not_Started
# 0       178435.0    89679.000000           1481.0
# 1       160933.0    88978.000000            611.0
# 2        41515.0    21019.000000            250.0
# 3        35561.0    17488.000000            221.0
# 4       109818.0    61334.000000            704.0
# ..           ...             ...              ...
# 635      12543.0     9428.000000             85.0
# 636      60089.0   301130.541139            366.0
# 637      12088.0     5922.000000             46.0
# 638      30741.0    17464.000000             42.0
# 639      76332.0    33128.000000            280.0
#
# [640 rows x 16 columns]

# %%
df=housing.merge(census,on=['District','State/UT'])

# %%
df.columns
# Out:
# Index(['District', 'Households_x', 'Households_Rural_x',
#        'Households_Rural_Dilapidated', 'Households_Rural_Livable',
#        'Households_Rural_Toilet_Premise', 'Households_Urban_x',
#        'Households_Urban_Dilapidated', 'Households_Urban_Livable',
#        'Households_Urban_Toilet_Premise', 'State/UT', 'Unnamed: 0',
#        'Population', 'Male', 'Female', 'Literate', 'Literate_Male',
#        'Literate_Female', 'Households_Rural_y', 'Households_Urban_y',
#        'Households_y', 'Young_and_Adult', 'Middle_Aged', 'Senior_Citizen',
#        'Age_Not_Started'],
#       dtype='object')

# %%
df=df[['State/UT','District','Households_y','Population']]

# %%
states=df['State/UT'].unique()

# %%
df=df.groupby('State/UT').sum()
df
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_20228\1909518913.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df=df.groupby('State/UT').sum()
#                              Households_y    Population
# State/UT
# Andaman and Nicobar Islands  1.416750e+05  3.805810e+05
# Andhra Pradesh               1.472919e+07  4.938680e+07
# Arunachal Pradesh            8.684286e+05  1.383727e+06
# Assam                        9.074503e+06  3.120558e+07
# Bihar                        2.341467e+07  1.040995e+08
# Chandigarh                   2.983670e+05  1.055450e+06
# Chhattisgarh                 7.015861e+06  2.554520e+07
# Dadra and Nagar Haveli       1.087830e+05  3.437090e+05
# Daman and Diu                8.992900e+04  2.432470e+05
# Goa                          5.765820e+05  1.458545e+06
# Gujarat                      1.752403e+07  6.043969e+07
# Haryana                      7.088008e+06  2.535146e+07
# Himachal Pradesh             2.933663e+06  6.864602e+06
# Jammu and Kashmir            3.501094e+06  1.226701e+07
# Jharkhand                    7.796033e+06  3.298813e+07
# Karnataka                    1.799907e+07  6.114031e+07
# Kerala                       1.121785e+07  3.340606e+07
# Laddakh                      1.025380e+05  2.742890e+05
# Lakshadweep                  2.124200e+04  6.447300e+04
# Madhya Pradesh               1.849876e+07  7.262681e+07
# Maharashtra                  3.356976e+07  1.123743e+08
# Manipur                      6.099640e+05  2.855794e+06
# Meghalaya                    7.214670e+05  2.966889e+06
# Mizoram                      2.694310e+05  1.097206e+06
# Nagaland                     5.344240e+05  1.978502e+06
# Nct Of Delhi                 4.605555e+06  1.678794e+07
# Orissa                       1.275913e+07  4.197422e+07
# Pondicherry                  3.879990e+05  1.247953e+06
# Punjab                       7.847447e+06  2.774334e+07
# Rajasthan                    1.797849e+07  6.854844e+07
# Sikkim                       1.690220e+05  6.105770e+05
# Tamil Nadu                   2.316672e+07  7.214703e+07
# Telangana                    1.007860e+07  3.519398e+07
# Tripura                      1.066863e+06  3.673917e+06
# Uttar Pradesh                4.517244e+07  1.998123e+08
# Uttarakhand                  3.383410e+06  1.008629e+07
# West Bengal                  2.534372e+07  9.127612e+07

# %%
df['Households_y']=round(df['Households_y'])
df['Population']=round(df['Population'])
df
# Out:
#                              Households_y   Population
# State/UT
# Andaman and Nicobar Islands      141675.0     380581.0
# Andhra Pradesh                 14729191.0   49386799.0
# Arunachal Pradesh                868429.0    1383727.0
# Assam                           9074503.0   31205576.0
# Bihar                          23414674.0  104099452.0
# Chandigarh                       298367.0    1055450.0
# Chhattisgarh                    7015861.0   25545198.0
# Dadra and Nagar Haveli           108783.0     343709.0
# Daman and Diu                     89929.0     243247.0
# Goa                              576582.0    1458545.0
# Gujarat                        17524030.0   60439692.0
# Haryana                         7088008.0   25351462.0
# Himachal Pradesh                2933663.0    6864602.0
# Jammu and Kashmir               3501094.0   12267013.0
# Jharkhand                       7796033.0   32988134.0
# Karnataka                      17999066.0   61140305.0
# Kerala                         11217853.0   33406061.0
# Laddakh                          102538.0     274289.0
# Lakshadweep                       21242.0      64473.0
# Madhya Pradesh                 18498763.0   72626809.0
# Maharashtra                    33569762.0  112374333.0
# Manipur                          609964.0    2855794.0
# Meghalaya                        721467.0    2966889.0
# Mizoram                          269431.0    1097206.0
# Nagaland                         534424.0    1978502.0
# Nct Of Delhi                    4605555.0   16787941.0
# Orissa                         12759133.0   41974218.0
# Pondicherry                      387999.0    1247953.0
# Punjab                          7847447.0   27743338.0
# Rajasthan                      17978493.0   68548437.0
# Sikkim                           169022.0     610577.0
# Tamil Nadu                     23166721.0   72147030.0
# Telangana                      10078599.0   35193978.0
# Tripura                         1066863.0    3673917.0
# Uttar Pradesh                  45172443.0  199812341.0
# Uttarakhand                     3383410.0   10086292.0
# West Bengal                    25343715.0   91276115.0

# %%
df['Per_100']=(df['Households_y']/df['Population'])*100

# %%
df
# Out:
#                              Households_y   Population    Per_100
# State/UT
# Andaman and Nicobar Islands      141675.0     380581.0  37.225978
# Andhra Pradesh                 14729191.0   49386799.0  29.824146
# Arunachal Pradesh                868429.0    1383727.0  62.760140
# Assam                           9074503.0   31205576.0  29.079748
# Bihar                          23414674.0  104099452.0  22.492601
# Chandigarh                       298367.0    1055450.0  28.269174
# Chhattisgarh                    7015861.0   25545198.0  27.464500
# Dadra and Nagar Haveli           108783.0     343709.0  31.649739
# Daman and Diu                     89929.0     243247.0  36.970240
# Goa                              576582.0    1458545.0  39.531314
# Gujarat                        17524030.0   60439692.0  28.994241
# Haryana                         7088008.0   25351462.0  27.958971
# Himachal Pradesh                2933663.0    6864602.0  42.736097
# Jammu and Kashmir               3501094.0   12267013.0  28.540721
# Jharkhand                       7796033.0   32988134.0  23.632840
# Karnataka                      17999066.0   61140305.0  29.438954
# Kerala                         11217853.0   33406061.0  33.580293
# Laddakh                          102538.0     274289.0  37.383198
# Lakshadweep                       21242.0      64473.0  32.947125
# Madhya Pradesh                 18498763.0   72626809.0  25.470984
# Maharashtra                    33569762.0  112374333.0  29.873158
# Manipur                          609964.0    2855794.0  21.358824
# Meghalaya                        721467.0    2966889.0  24.317290
# Mizoram                          269431.0    1097206.0  24.556100
# Nagaland                         534424.0    1978502.0  27.011547
# Nct Of Delhi                    4605555.0   16787941.0  27.433710
# Orissa                         12759133.0   41974218.0  30.397548
# Pondicherry                      387999.0    1247953.0  31.090834
# Punjab                          7847447.0   27743338.0  28.285879
# Rajasthan                      17978493.0   68548437.0  26.227430
# Sikkim                           169022.0     610577.0  27.682340
# Tamil Nadu                     23166721.0   72147030.0  32.110429
# Telangana                      10078599.0   35193978.0  28.637283
# Tripura                         1066863.0    3673917.0  29.038843
# Uttar Pradesh                  45172443.0  199812341.0  22.607434
# Uttarakhand                     3383410.0   10086292.0  33.544637
# West Bengal                    25343715.0   91276115.0  27.765988

# %%
values=df['Per_100'].tolist()

# %%
plt.bar(states, values,color='#FFE0AC')

# Add chart title and axis labels
plt.title('District-wise Data')
plt.xlabel('states')
plt.ylabel('Data')
plt.xticks(rotation=90)
# Show the chart
plt.show()
