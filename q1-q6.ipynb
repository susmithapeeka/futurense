# %%
import pandas as pd
import numpy as np

# %% [markdown]
# **Problem Statement 1: (Keep the relevant data)**
# **Problem Statement 2: (Rename the Column names)**

# %%
census=pd.read_csv('Data\census_2011.csv',usecols=['State name','District name','Population','Male','Female','Literate','Male_Literate','Female_Literate','Rural_Households','Urban_Households','Households','Age_Group_0_29','Age_Group_30_49','Age_Group_50','Age not stated'])

# %%
census
# Out:
#                       State name              District name  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Male_Literate  Female_Literate  \
# ...

# %%
census.rename(columns={'State name':'State/UT',
               'District name':'District',
               'Male_Literate':'Literate_Male',
               'Female_Literate':'Literate_Female',
               'Rural_Households':'Households_Rural',
               'Urban_Households':'Households_Urban',
               'Age_Group_0_29':'Young_and_Adult',
               'Age_Group_30_49':'Middle_Aged',
               'Age_Group_50':'Senior_Citizen',
               'Age not stated':' Age_Not_Stated'},inplace=True)

# %%
census.head()
# Out:
#             State/UT     District  Population      Male    Female  Literate  \
# 0  JAMMU AND KASHMIR      Kupwara    870354.0  474190.0  396164.0  439654.0
# 1  JAMMU AND KASHMIR       Badgam    753745.0       NaN  355704.0  335649.0
# 2  JAMMU AND KASHMIR  Leh(Ladakh)    133487.0   78971.0   54516.0   93770.0
# 3  JAMMU AND KASHMIR       Kargil    140802.0       NaN   63017.0       NaN
# 4  JAMMU AND KASHMIR        Punch         NaN  251899.0  224936.0  261724.0
#
#    Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 0       282823.0         156831.0          158438.0               NaN
# 1       207741.0         127908.0          160649.0           27190.0
# 2        62834.0          30936.0           36920.0           17474.0
# 3        56301.0          29935.0           40370.0            7774.0
# 4       163333.0          98391.0          132139.0           15269.0
#
#    Households  Young_and_Adult  Middle_Aged  Senior_Citizen   Age_Not_Stated
# ...

# %%
point1=census.copy()

# %% [markdown]
# **Problem Statement 3: (Rename State/UT Names)**

# %%
point1
# Out:
#                         State/UT                   District  Population  \
# 0              JAMMU AND KASHMIR                    Kupwara    870354.0
# 1              JAMMU AND KASHMIR                     Badgam    753745.0
# 2              JAMMU AND KASHMIR                Leh(Ladakh)    133487.0
# 3              JAMMU AND KASHMIR                     Kargil    140802.0
# 4              JAMMU AND KASHMIR                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  PONDICHERRY                       Mahe     41816.0
# 636                  PONDICHERRY                   Karaikal    200222.0
# 637  ANDAMAN AND NICOBAR ISLANDS                   Nicobars     36842.0
# 638  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman    105597.0
# 639  ANDAMAN AND NICOBAR ISLANDS              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %%
census['State/UT']
# Out:
# 0                JAMMU AND KASHMIR
# 1                JAMMU AND KASHMIR
# 2                JAMMU AND KASHMIR
# 3                JAMMU AND KASHMIR
# 4                JAMMU AND KASHMIR
#                   ...
# 635                    PONDICHERRY
# 636                    PONDICHERRY
# 637    ANDAMAN AND NICOBAR ISLANDS
# 638    ANDAMAN AND NICOBAR ISLANDS
# 639    ANDAMAN AND NICOBAR ISLANDS
# Name: State/UT, Length: 640, dtype: object

# %%
def func(word):
    word=word.title()
    word=word.replace(' And ',' and ')
    return word

# %%
census["State/UT"]=census['State/UT'].apply(func)

# %%
census["District"]=census["District"].apply(func)

# %%
census['State/UT'].value_counts()
# Out:
# Uttar Pradesh                  71
# Madhya Pradesh                 50
# Bihar                          38
# Maharashtra                    35
# Rajasthan                      33
# Tamil Nadu                     32
# Karnataka                      30
# Orissa                         30
# Assam                          27
# Gujarat                        26
# Jharkhand                      24
# Andhra Pradesh                 23
# Jammu and Kashmir              22
# Haryana                        21
# Punjab                         20
# West Bengal                    19
# Chhattisgarh                   18
# Arunachal Pradesh              16
# Kerala                         14
# Uttarakhand                    13
# Himachal Pradesh               12
# Nagaland                       11
# Manipur                         9
# Nct Of Delhi                    9
# Mizoram                         8
# Meghalaya                       7
# Tripura                         4
# ...

# %%
copy2=census.copy()

# %% [markdown]
# **Problem Statement 4: (New State/UT formation)**

# %%
telangana=pd.read_csv('Data/Telangana.txt',header=None)

# %%
liststate=telangana[0].tolist()

# %%
census.loc[census['District'].isin(liststate),'State/UT']='Telangana'

# %%
census[census['State/UT']=='Telangana']
# Out:
#       State/UT     District  Population       Male     Female   Literate  \
# 531  Telangana     Adilabad   2741239.0        NaN  1371642.0  1483347.0
# 532  Telangana    Nizamabad   2551335.0  1250641.0  1300694.0  1389810.0
# 533  Telangana   Karimnagar   3776269.0  1880800.0  1895469.0  2206829.0
# 534  Telangana        Medak   3033288.0  1523030.0  1510258.0  1637137.0
# 535  Telangana    Hyderabad   3943323.0  2018575.0  1924748.0  2892155.0
# 536  Telangana   Rangareddy   5296741.0  2701008.0  2595733.0        NaN
# 537  Telangana  Mahbubnagar   4053028.0  2050386.0  2002642.0  1940646.0
# 538  Telangana     Nalgonda   3488809.0  1759772.0  1729037.0  2001019.0
# 539  Telangana     Warangal   3512576.0  1759281.0  1753295.0  2065023.0
# 540  Telangana      Khammam   2797370.0  1390988.0  1406382.0  1630234.0
#
#      Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 531       856350.0         626997.0               NaN          220248.0
# ...

# %% [markdown]
# ***In 2019 Laddakh was formed after it split from Jammu and Kashmir, which included the districts Leh and Kargil.  Rename the State/UT From “Jammu and Kashmir” to “Laddakh” for the given districts.***

# %%
newdistrics=['Leh(Ladakh)','Kargil']

# %%
census.loc[census['District'].isin(newdistrics),'State/UT']='Laddakh'

# %%
census[census['State/UT']=='Laddakh']
# Out:
#   State/UT     District  Population     Male   Female  Literate  \
# 2  Laddakh  Leh(Ladakh)    133487.0  78971.0  54516.0   93770.0
# 3  Laddakh       Kargil    140802.0      NaN  63017.0       NaN
#
#    Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 2        62834.0          30936.0           36920.0           17474.0
# 3        56301.0          29935.0           40370.0            7774.0
#
#    Households  Young_and_Adult  Middle_Aged  Senior_Citizen   Age_Not_Stated
# 2     54394.0          70703.0      41515.0             NaN            250.0
# 3     48144.0          87532.0      35561.0         17488.0            221.0

# %%
census
# Out:
#                         State/UT                   District  Population  \
# 0              Jammu and Kashmir                    Kupwara    870354.0
# 1              Jammu and Kashmir                     Badgam    753745.0
# 2                        Laddakh                Leh(Ladakh)    133487.0
# 3                        Laddakh                     Kargil    140802.0
# 4              Jammu and Kashmir                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  Pondicherry                       Mahe     41816.0
# 636                  Pondicherry                   Karaikal    200222.0
# 637  Andaman and Nicobar Islands                   Nicobars     36842.0
# 638  Andaman and Nicobar Islands  North  and Middle Andaman    105597.0
# 639  Andaman and Nicobar Islands              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %%
copy3=census.copy()

# %% [markdown]
# **Problem Statement 5: (Find and process Missing Data)**
#
#
# Find and store the percentage of data missing for each column.
# Some data can be found and filled in by using information from other cells. Try to find the correct data by using information from other cells and filling it in. Find and store the percentage of data missing for each column.
#
# Hint:
# * Population = Male + Female
# * Literate = Literate_Male + Literate_Female
# * Population  = Young_and_Adult+  Middle_Aged + Senior_Citizen +
# * Age_Not_Stated
# * Households = Households_Rural + Households_Urban

# %%
missingData=census.copy()

# %%
x=missingData.isnull().mean()*100

# %%
x
# Out:
# State/UT            0.00000
# District            0.00000
# Population          4.68750
# Male                4.68750
# Female              5.15625
# Literate            5.62500
# Literate_Male       4.84375
# Literate_Female     4.21875
# Households_Rural    6.56250
# Households_Urban    5.15625
# Households          5.00000
# Young_and_Adult     4.84375
# Middle_Aged         4.68750
# Senior_Citizen      4.84375
#  Age_Not_Stated     5.46875
# dtype: float64

# %%
census
# Out:
#                         State/UT                   District  Population  \
# 0              Jammu and Kashmir                    Kupwara    870354.0
# 1              Jammu and Kashmir                     Badgam    753745.0
# 2                        Laddakh                Leh(Ladakh)    133487.0
# 3                        Laddakh                     Kargil    140802.0
# 4              Jammu and Kashmir                      Punch         NaN
# ..                           ...                        ...         ...
# 635                  Pondicherry                       Mahe     41816.0
# 636                  Pondicherry                   Karaikal    200222.0
# 637  Andaman and Nicobar Islands                   Nicobars     36842.0
# 638  Andaman and Nicobar Islands  North  and Middle Andaman    105597.0
# 639  Andaman and Nicobar Islands              South Andaman         NaN
#
#          Male    Female  Literate  Literate_Male  Literate_Female  \
# ...

# %%
missingData['Male'].fillna(missingData['Population']-missingData['Female'],inplace=True)

# %%
missingData[missingData['Male'].isnull()]
# Out:
#       State/UT District  Population  Male    Female   Literate  Literate_Male  \
# 561  Karnataka  Dharwad         NaN   NaN  909817.0  1301664.0       711776.0
#
#      Literate_Female  Households_Rural  Households_Urban  Households  \
# 561         589888.0          199707.0          283397.0    483104.0
#
#      Young_and_Adult  Middle_Aged  Senior_Citizen   Age_Not_Stated
# 561        1017935.0          NaN        322577.0            823.0

# %%
missingData['Female'].fillna(missingData['Population']-missingData['Male'],inplace=True)

# %%
missingData[missingData['Female'].isnull()]
# Out:
# Empty DataFrame
# Columns: [State/UT, District, Population, Male, Female, Literate, Literate_Male, Literate_Female, Households_Rural, Households_Urban, Households, Young_and_Adult, Middle_Aged, Senior_Citizen,  Age_Not_Stated]
# Index: []

# %%
missingData['Population'].fillna(missingData['Female']+missingData['Male'],inplace=True)

# %%
missingData[missingData['Population'].isnull()]
# Out:
#       State/UT District  Population  Male    Female   Literate  Literate_Male  \
# 561  Karnataka  Dharwad         NaN   NaN  909817.0  1301664.0       711776.0
#
#      Literate_Female  Households_Rural  Households_Urban  Households  \
# 561         589888.0          199707.0          283397.0    483104.0
#
#      Young_and_Adult  Middle_Aged  Senior_Citizen   Age_Not_Stated
# 561        1017935.0          NaN        322577.0            823.0

# %%
missingData.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population           1
# Male                 1
# Female               0
# Literate            36
# Literate_Male       31
# Literate_Female     27
# Households_Rural    42
# Households_Urban    33
# Households          32
# Young_and_Adult     31
# Middle_Aged         30
# Senior_Citizen      31
#  Age_Not_Stated     35
# dtype: int64

# %%
#literate

missingData['Literate'].fillna(missingData['Literate_Male']+missingData['Literate_Female'],inplace=True)

# %%
missingData['Literate_Male'].fillna(missingData['Literate']-missingData['Literate_Female'],inplace=True)

# %%
missingData['Literate_Female'].fillna(missingData['Literate']-missingData['Literate_Male'],inplace=True)

# %%
missingData[missingData['Literate'].isnull()]
# Out:
#         State/UT        District  Population       Male     Female  Literate  \
# 329  West Bengal  Uttar Dinajpur   3007134.0  1551066.0  1456068.0       NaN
# 568    Karnataka           Udupi   1177361.0   562131.0   615230.0       NaN
#
#      Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 329       853495.0              NaN          683981.0           94269.0
# 568            NaN         460725.0          269817.0          115572.0
#
#      Households  Young_and_Adult  Middle_Aged  Senior_Citizen   Age_Not_Stated
# 329    778250.0        1916033.0     704859.0        385155.0           1087.0
# 568    385389.0              NaN     340903.0        276234.0            659.0

# %%
missingData['Households'].fillna(missingData['Households_Rural']+missingData['Households_Urban'],inplace=True)

# %%
missingData['Households_Rural'].fillna(missingData['Households']-missingData['Households_Urban'],inplace=True)

# %%
missingData['Households_Urban'].fillna(missingData['Households']-missingData['Households_Rural'],inplace=True)

# %%
missingData[missingData['Households_Rural'].isnull()]
# Out:
#            State/UT   District  Population       Male     Female   Literate  \
# 104       Rajasthan  Bharatpur   2548462.0  1355726.0  1192736.0  1480869.0
# 364       Jharkhand     Khunti    531885.0   266335.0   265550.0   284575.0
# 400    Chhattisgarh    Surguja   2359886.0  1193129.0  1166757.0  1187941.0
# 401    Chhattisgarh    Jashpur    851669.0   424747.0   426922.0   495415.0
# 460  Madhya Pradesh    Anuppur    749237.0   379114.0   370123.0   436595.0
# 553  Andhra Pradesh   Chittoor   4174064.0  2090204.0  2083860.0  2667878.0
#
#      Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 104       943910.0         536959.0               NaN          129697.0
# 364       164741.0         119834.0               NaN               NaN
# 400       694686.0         493255.0               NaN           65167.0
# 401       280656.0         214759.0               NaN           20722.0
# 460       254120.0         182475.0               NaN               NaN
# ...

# %%
#filling the one with population null value
missingData[missingData['Population'].isnull()]
# Out:
#       State/UT District  Population  Male    Female   Literate  Literate_Male  \
# 561  Karnataka  Dharwad         NaN   NaN  909817.0  1301664.0       711776.0
#
#      Literate_Female  Households_Rural  Households_Urban  Households  \
# 561         589888.0          199707.0          283397.0    483104.0
#
#      Young_and_Adult  Middle_Aged  Senior_Citizen   Age_Not_Stated
# 561        1017935.0          NaN        322577.0            823.0

# %%
missingData.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population           1
# Male                 1
# Female               0
# Literate             2
# Literate_Male        2
# Literate_Female      2
# Households_Rural     6
# Households_Urban     3
# Households           5
# Young_and_Adult     31
# Middle_Aged         30
# Senior_Citizen      31
#  Age_Not_Stated     35
# dtype: int64

# %%
#fill nulls of young_adult,middle_aged,senior_citizen,age_not_Stated

missingData['Young_and_Adult'].fillna(missingData['Population']-missingData['Senior_Citizen']-missingData['Middle_Aged']-missingData[' Age_Not_Stated'],inplace=True)

# %%
missingData.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population           1
# Male                 1
# Female               0
# Literate             2
# Literate_Male        2
# Literate_Female      2
# Households_Rural     6
# Households_Urban     3
# Households           5
# Young_and_Adult      4
# Middle_Aged         30
# Senior_Citizen      31
#  Age_Not_Stated     35
# dtype: int64

# %%
missingData['Senior_Citizen'].fillna(missingData['Population']-missingData['Young_and_Adult']-missingData['Middle_Aged']-missingData[' Age_Not_Stated'],inplace=True)

# %%
missingData.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population           1
# Male                 1
# Female               0
# Literate             2
# Literate_Male        2
# Literate_Female      2
# Households_Rural     6
# Households_Urban     3
# Households           5
# Young_and_Adult      4
# Middle_Aged         30
# Senior_Citizen       8
#  Age_Not_Stated     35
# dtype: int64

# %%
missingData['Middle_Aged'].fillna(missingData['Population']-missingData['Young_and_Adult']-missingData['Senior_Citizen']-missingData[' Age_Not_Stated'],inplace=True)

# %%
missingData['Middle_Aged'].fillna(missingData['Population']-missingData['Young_and_Adult']-missingData['Senior_Citizen']-missingData[' Age_Not_Stated'],inplace=True)

# %%
missingData.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population           1
# Male                 1
# Female               0
# Literate             2
# Literate_Male        2
# Literate_Female      2
# Households_Rural     6
# Households_Urban     3
# Households           5
# Young_and_Adult      4
# Middle_Aged          6
# Senior_Citizen       8
#  Age_Not_Stated     35
# dtype: int64

# %%
missingData.rename(columns={' Age_Not_Stated':'Age_Not_Started'},inplace=True)

# %%
missingData['Age_Not_Started'].fillna(missingData['Population']-missingData['Young_and_Adult']-missingData['Senior_Citizen']-missingData['Middle_Aged'],inplace=True)

# %%
missingData.isnull().sum()
# Out:
# State/UT            0
# District            0
# Population          1
# Male                1
# Female              0
# Literate            2
# Literate_Male       2
# Literate_Female     2
# Households_Rural    6
# Households_Urban    3
# Households          5
# Young_and_Adult     4
# Middle_Aged         6
# Senior_Citizen      8
# Age_Not_Started     3
# dtype: int64

# %%
copy4=missingData.copy()

# %%
missingData[missingData['Senior_Citizen'].isnull()]
# Out:
#               State/UT        District  Population       Male     Female  \
# 11   Jammu and Kashmir         Pulwama    560440.0   293064.0   267376.0
# 70             Haryana     Yamunanagar   1214205.0   646718.0   567487.0
# 362          Jharkhand         Jamtara    791042.0   404830.0   386212.0
# 460     Madhya Pradesh         Anuppur    749237.0   379114.0   370123.0
# 470            Gujarat        Mahesana   2035064.0  1056520.0   978544.0
# 622         Tamil Nadu         Madurai   3038252.0  1526475.0  1511777.0
# 625         Tamil Nadu  Ramanathapuram   1353445.0   682658.0   670787.0
# 636        Pondicherry        Karaikal    200222.0    97809.0   102413.0
#
#       Literate  Literate_Male  Literate_Female  Households_Rural  \
# 11    293958.0       178326.0         115632.0          147520.0
# 70    832457.0       474793.0         357664.0          214464.0
# 362   426312.0       258260.0         168052.0          165555.0
# ...

# %%
#filling with mean values

missingData['Population'].fillna(missingData['Population'].mean(),inplace=True)

# %%
missingData['Male'].fillna(missingData['Male'].mean(),inplace=True)

# %%
missingData['Literate'].fillna(missingData['Literate'].mean(),inplace=True)

# %%
missingData['Literate_Male'].fillna(missingData['Literate_Male'].mean(),inplace=True)

# %%
missingData['Literate_Female'].fillna(missingData['Literate_Female'].mean(),inplace=True)

# %%
missingData['Households'].fillna(missingData['Households'].mean(),inplace=True)

# %%
missingData['Households_Rural'].fillna(missingData['Households_Rural'].mean(),inplace=True)

# %%
missingData['Households_Urban'].fillna(missingData['Households_Urban'].mean(),inplace=True)

# %%
missingData['Young_and_Adult'].fillna(missingData['Young_and_Adult'].mean(),inplace=True)

# %%
missingData['Middle_Aged'].fillna(missingData['Middle_Aged'].mean(),inplace=True)

# %%
missingData['Senior_Citizen'].fillna(missingData['Senior_Citizen'].mean(),inplace=True)

# %%
missingData['Age_Not_Started'].fillna(missingData['Senior_Citizen'].mean(),inplace=True)

# %%
finalDataCopy=missingData.copy()

# %%
missingData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          640 non-null    object
#  1   District          640 non-null    object
#  2   Population        640 non-null    float64
#  3   Male              640 non-null    float64
#  4   Female            640 non-null    float64
#  5   Literate          640 non-null    float64
#  6   Literate_Male     640 non-null    float64
#  7   Literate_Female   640 non-null    float64
#  8   Households_Rural  640 non-null    float64
#  9   Households_Urban  640 non-null    float64
#  10  Households        640 non-null    float64
#  11  Young_and_Adult   640 non-null    float64
#  12  Middle_Aged       640 non-null    float64
#  13  Senior_Citizen    640 non-null    float64
#  14  Age_Not_Started   640 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %% [markdown]
# **Visualisation**

# %%
import seaborn as sns

# %%
#before
sns.heatmap(copy4.isnull())
# Out:
# <Axes: >

# %%
census.isnull().sum()
# Out:
# State/UT             0
# District             0
# Population          30
# Male                30
# Female              33
# Literate            36
# Literate_Male       31
# Literate_Female     27
# Households_Rural    42
# Households_Urban    33
# Households          32
# Young_and_Adult     31
# Middle_Aged         30
# Senior_Citizen      31
#  Age_Not_Stated     35
# dtype: int64

# %%
sns.heatmap(census.isnull())
# Out:
# <Axes: >

# %%
sns.heatmap(copy4.isnull())
# Out:
# <Axes: >

# %%
#Finding percentage of missing values
missing_value_pct={}
for i in  census.columns:
    missing_value_pct[i]=(census[i].isna().sum())/len(census[i])*100
missing_value_pct
# Out:
# {'State/UT': 0.0,
#  'District': 0.0,
#  'Population': 4.6875,
#  'Male': 4.6875,
#  'Female': 5.15625,
#  'Literate': 5.625,
#  'Literate_Male': 4.84375,
#  'Literate_Female': 4.21875,
#  'Households_Rural': 6.5625,
#  'Households_Urban': 5.15625,
#  'Households': 5.0,
#  'Young_and_Adult': 4.84375,
#  'Middle_Aged': 4.6875,
#  'Senior_Citizen': 4.84375,
#  ' Age_Not_Stated': 5.46875}

# %%
missing_value_pct_new={}
for i in  copy4.columns:
    missing_value_pct_new[i]=(copy4[i].isna().sum())/len(copy4[i])*100
missing_value_pct_new
# Out:
# {'State/UT': 0.0,
#  'District': 0.0,
#  'Population': 0.15625,
#  'Male': 0.15625,
#  'Female': 0.0,
#  'Literate': 0.3125,
#  'Literate_Male': 0.3125,
#  'Literate_Female': 0.3125,
#  'Households_Rural': 0.9375,
#  'Households_Urban': 0.46875,
#  'Households': 0.78125,
#  'Young_and_Adult': 0.625,
#  'Middle_Aged': 0.9375,
#  'Senior_Citizen': 1.25,
#  'Age_Not_Started': 0.46875}

# %%
p=pd.DataFrame([missing_value_pct,missing_value_pct_new]).T
p.columns=['Before Filling','After filling']
p.plot.bar()
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
sns.displot(
    data=copy3.isna().melt(value_name="missing"),
    y="variable",
    hue="missing",
    multiple="fill",
    aspect=1.25
)

# Change the x-label and y-label
sns.set(font_scale=1.5)
plt.xlabel('Percentage of missing values')
plt.ylabel('Variables')
plt.show()

# %% [markdown]
# **Problem Statement 6: (Save Data)**
# Save the processed data to a CSV file named “census.csv” in the “Clean_Data” folder.
#
# finaldataCopy has all the null values handled

# %%
finalDataCopy.to_csv('clean_Data/Clean_Data/clean_census.csv')

# %%
finalDataCopy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   State/UT          640 non-null    object
#  1   District          640 non-null    object
#  2   Population        640 non-null    float64
#  3   Male              640 non-null    float64
#  4   Female            640 non-null    float64
#  5   Literate          640 non-null    float64
#  6   Literate_Male     640 non-null    float64
#  7   Literate_Female   640 non-null    float64
#  8   Households_Rural  640 non-null    float64
#  9   Households_Urban  640 non-null    float64
#  10  Households        640 non-null    float64
#  11  Young_and_Adult   640 non-null    float64
#  12  Middle_Aged       640 non-null    float64
#  13  Senior_Citizen    640 non-null    float64
#  14  Age_Not_Started   640 non-null    float64
# dtypes: float64(13), object(2)
# memory usage: 75.1+ KB

# %% [markdown]
# **Problem Statement 7: (Process the relevant data)**
# From the housing data(Data/housing.csv) read the following columns which may be relevant to the requirement.
#
#
# Calculate the data and rename the column names and save it in a CSV file named “housing.csv” in the “Clean_Data” folder, such that it  has the following column names:
# * District
# * Households_Rural
# * Households_Rural_Livable
# * Households_Rural_Dilapidated
# * Households_Rural_Toilet_Premise
# * Households_Urban
# * Households_Urban_Livable
# * Households_Urban_Dilapidated
# * Households_Urban_Toilet_Premise

# %%
census.shape
# Out:
# (640, 15)

# %%
housingw=pd.read_csv('Data/housing.csv')

# %%
list1=housingw.columns

# %%
list1
# Out:
# Index(['State Code', 'State Name', 'District Code', 'District Name',
#        'Tehsil Code', 'Tehsil Name', 'Town Code/Village code', 'Ward No',
#        'Area Name', 'Rural/Urban',
#        ...
#        'Contition_T_Total', 'Contition_T_Good', 'Contition_T_Livable',
#        'Contition_T_Dilapidated', 'Contition_R_Total', 'Residence_Good',
#        'Residence_Livable', 'Residence_Dilapidated', 'Residence_cum_other',
#        'Residence_cum_Good'],
#       dtype='object', length=156)

# %%
housing=pd.read_csv('Data/housing.csv',usecols=['District Name','Rural/Urban','Total Number of households','Total Number of Livable','Total Number of Dilapidated','Latrine_premise'])

# %%
housing
# Out:
#                 District Name Rural/Urban  Total Number of households  \
# 0                     Kupwara       Rural                         100
# 1                     Kupwara       Total                         100
# 2                     Kupwara       Urban                         100
# 3                      Badgam       Rural                         100
# 4                      Badgam       Total                         100
# ...                       ...         ...                         ...
# 1903  North  & Middle Andaman       Total                         100
# 1904  North  & Middle Andaman       Urban                         100
# 1905            South Andaman       Rural                         100
# 1906            South Andaman       Total                         100
# 1907            South Andaman       Urban                         100
#
#       Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# ...

# %%
housing.shape
# Out:
# (1908, 6)

# %%
housing.isnull().sum()
# Out:
# District Name                  0
# Rural/Urban                    0
# Total Number of households     0
# Total Number of Livable        0
# Total Number of Dilapidated    0
# Latrine_premise                0
# dtype: int64

# %%
housing.head()
# Out:
#   District Name Rural/Urban  Total Number of households  \
# 0       Kupwara       Rural                         100
# 1       Kupwara       Total                         100
# 2       Kupwara       Urban                         100
# 3        Badgam       Rural                         100
# 4        Badgam       Total                         100
#
#    Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 0                     58.1                          8.3             48.9
# 1                     57.3                          7.9             50.9
# 2                     49.5                          4.8             70.2
# 3                     46.3                          3.9             83.3
# 4                     44.7                          3.8             84.3

# %%
housing.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1908 entries, 0 to 1907
# Data columns (total 6 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   District Name                1908 non-null   object
#  1   Rural/Urban                  1908 non-null   object
#  2   Total Number of households   1908 non-null   int64
#  3   Total Number of Livable      1908 non-null   float64
#  4   Total Number of Dilapidated  1908 non-null   float64
#  5   Latrine_premise              1908 non-null   float64
# dtypes: float64(3), int64(1), object(2)
# memory usage: 89.6+ KB

# %%
housing.set_index(['Rural/Urban'],inplace=True)

# %%
rural=housing.loc['Rural'].copy()

# %%
urban=housing.loc['Urban'].copy()
urban.reset_index(drop=True, inplace=True)

# %%
urban.head()
# Out:
#   District Name  Total Number of households  Total Number of Livable  \
# 0       Kupwara                         100                     49.5
# 1        Badgam                         100                     33.8
# 2   Leh(Ladakh)                         100                     54.6
# 3        Kargil                         100                     68.8
# 4         Punch                         100                     27.3
#
#    Total Number of Dilapidated  Latrine_premise
# 0                          4.8             70.2
# 1                          2.6             90.4
# 2                          1.1             95.8
# 3                          1.2             97.5
# 4                          0.8             75.3

# %%
rural.head()
rural.reset_index(drop=True, inplace=True)

# %%
rural
# Out:
#                District Name  Total Number of households  \
# 0                    Kupwara                         100
# 1                     Badgam                         100
# 2                Leh(Ladakh)                         100
# 3                     Kargil                         100
# 4                      Punch                         100
# ..                       ...                         ...
# 626               Puducherry                         100
# 627                 Karaikal                         100
# 628                 Nicobars                         100
# 629  North  & Middle Andaman                         100
# 630            South Andaman                         100
#
#      Total Number of Livable  Total Number of Dilapidated  Latrine_premise
# 0                       58.1                          8.3             48.9
# 1                       46.3                          3.9             83.3
# ...

# %%
rural.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 631 entries, 0 to 630
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   District Name                631 non-null    object
#  1   Total Number of households   631 non-null    int64
#  2   Total Number of Livable      631 non-null    float64
#  3   Total Number of Dilapidated  631 non-null    float64
#  4   Latrine_premise              631 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 24.8+ KB

# %%
urban.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 637 entries, 0 to 636
# Data columns (total 5 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   District Name                637 non-null    object
#  1   Total Number of households   637 non-null    int64
#  2   Total Number of Livable      637 non-null    float64
#  3   Total Number of Dilapidated  637 non-null    float64
#  4   Latrine_premise              637 non-null    float64
# dtypes: float64(3), int64(1), object(1)
# memory usage: 25.0+ KB

# %%
ft=rural.merge(urban,how='inner',on="District Name",suffixes=('_rural','_urban'))

# %%
ft
# Out:
#                District Name  Total Number of households_rural  \
# 0                    Kupwara                               100
# 1                     Badgam                               100
# 2                Leh(Ladakh)                               100
# 3                     Kargil                               100
# 4                      Punch                               100
# ..                       ...                               ...
# 635                 Tiruppur                               100
# 636               Puducherry                               100
# 637                 Karaikal                               100
# 638  North  & Middle Andaman                               100
# 639            South Andaman                               100
#
#      Total Number of Livable_rural  Total Number of Dilapidated_rural  \
# 0                             58.1                                8.3
# ...

# %%
ft.columns
# Out:
# Index(['District Name', 'Total Number of households_rural',
#        'Total Number of Livable_rural', 'Total Number of Dilapidated_rural',
#        'Latrine_premise_rural', 'Total Number of households_urban',
#        'Total Number of Livable_urban', 'Total Number of Dilapidated_urban',
#        'Latrine_premise_urban'],
#       dtype='object')

# %%
ft.columns=['District','Households_Rural','Households_Rural_Livable','Households_Rural_Dilapidated','Households_Rural_Toilet_Premise','Households_Urban','Households_Urban_Livable','Households_Urban_Dilapidated','Households_Urban_Toilet_Premise']

# %%
ft
# Out:
#                     District  Households_Rural  Households_Rural_Livable  \
# 0                    Kupwara               100                      58.1
# 1                     Badgam               100                      46.3
# 2                Leh(Ladakh)               100                      51.5
# 3                     Kargil               100                      73.3
# 4                      Punch               100                      59.5
# ..                       ...               ...                       ...
# 635                 Tiruppur               100                      27.6
# 636               Puducherry               100                      31.9
# 637                 Karaikal               100                      36.8
# 638  North  & Middle Andaman               100                      44.3
# 639            South Andaman               100                      33.5
#
#      Households_Rural_Dilapidated  Households_Rural_Toilet_Premise  \
# ...

# %%
ft['Households_Rural_Livable']
# Out:
# 0      58.1
# 1      46.3
# 2      51.5
# 3      73.3
# 4      59.5
#        ...
# 635    27.6
# 636    31.9
# 637    36.8
# 638    44.3
# 639    33.5
# Name: Households_Rural_Livable, Length: 640, dtype: float64

# %%
finalDataCopy.head()
# Out:
#             State/UT     District  Population      Male    Female  Literate  \
# 0  Jammu and Kashmir      Kupwara    870354.0  474190.0  396164.0  439654.0
# 1  Jammu and Kashmir       Badgam    753745.0  398041.0  355704.0  335649.0
# 2            Laddakh  Leh(Ladakh)    133487.0   78971.0   54516.0   93770.0
# 3            Laddakh       Kargil    140802.0   77785.0   63017.0   86236.0
# 4  Jammu and Kashmir        Punch    476835.0  251899.0  224936.0  261724.0
#
#    Literate_Male  Literate_Female  Households_Rural  Households_Urban  \
# 0       282823.0         156831.0          158438.0           23226.0
# 1       207741.0         127908.0          160649.0           27190.0
# 2        62834.0          30936.0           36920.0           17474.0
# 3        56301.0          29935.0           40370.0            7774.0
# 4       163333.0          98391.0          132139.0           15269.0
#
#    Households  Young_and_Adult  Middle_Aged  Senior_Citizen  Age_Not_Started
# ...

# %%
households=finalDataCopy[['Households_Rural','Households_Urban','Households','District']]

# %%
households
# Out:
#      Households_Rural  Households_Urban  Households                   District
# 0            158438.0           23226.0    181664.0                    Kupwara
# 1            160649.0           27190.0    187839.0                     Badgam
# 2             36920.0           17474.0     54394.0                Leh(Ladakh)
# 3             40370.0            7774.0     48144.0                     Kargil
# 4            132139.0           15269.0    147408.0                      Punch
# ..                ...               ...         ...                        ...
# 635               0.0           12110.0     12110.0                       Mahe
# 636           35618.0           33715.0     69333.0                   Karaikal
# 637           15958.0               0.0     15958.0                   Nicobars
# 638           39091.0            1094.0     40185.0  North  and Middle Andaman
# 639           34901.0           50631.0     85532.0              South Andaman
#
# [640 rows x 4 columns]

# %%
households
# Out:
#      Households_Rural  Households_Urban  Households                   District
# 0            158438.0           23226.0    181664.0                    Kupwara
# 1            160649.0           27190.0    187839.0                     Badgam
# 2             36920.0           17474.0     54394.0                Leh(Ladakh)
# 3             40370.0            7774.0     48144.0                     Kargil
# 4            132139.0           15269.0    147408.0                      Punch
# ..                ...               ...         ...                        ...
# 635               0.0           12110.0     12110.0                       Mahe
# 636           35618.0           33715.0     69333.0                   Karaikal
# 637           15958.0               0.0     15958.0                   Nicobars
# 638           39091.0            1094.0     40185.0  North  and Middle Andaman
# 639           34901.0           50631.0     85532.0              South Andaman
#
# [640 rows x 4 columns]

# %%
households['Households_Rural_Livable']=households['Households_Rural']*(ft['Households_Rural_Livable']/100)
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_18032\2075193979.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   households['Households_Rural_Livable']=households['Households_Rural']*(ft['Households_Rural_Livable']/100)

# %%
ft
# Out:
#                     District  Households_Rural  Households_Rural_Livable  \
# 0                    Kupwara               100                      58.1
# 1                     Badgam               100                      46.3
# 2                Leh(Ladakh)               100                      51.5
# 3                     Kargil               100                      73.3
# 4                      Punch               100                      59.5
# ..                       ...               ...                       ...
# 635                 Tiruppur               100                      27.6
# 636               Puducherry               100                      31.9
# 637                 Karaikal               100                      36.8
# 638  North  & Middle Andaman               100                      44.3
# 639            South Andaman               100                      33.5
#
#      Households_Rural_Dilapidated  Households_Rural_Toilet_Premise  \
# ...

# %%
households['Households_Rural_Dilapidated']=households['Households_Rural']*(ft['Households_Rural_Dilapidated']/100)
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_18032\859411592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   households['Households_Rural_Dilapidated']=households['Households_Rural']*(ft['Households_Rural_Dilapidated']/100)

# %%
households
# Out:
#      Households_Rural  Households_Urban  Households  \
# 0            158438.0           23226.0    181664.0
# 1            160649.0           27190.0    187839.0
# 2             36920.0           17474.0     54394.0
# 3             40370.0            7774.0     48144.0
# 4            132139.0           15269.0    147408.0
# ..                ...               ...         ...
# 635               0.0           12110.0     12110.0
# 636           35618.0           33715.0     69333.0
# 637           15958.0               0.0     15958.0
# 638           39091.0            1094.0     40185.0
# 639           34901.0           50631.0     85532.0
#
#                       District  Households_Rural_Livable  \
# 0                      Kupwara                 92052.478
# 1                       Badgam                 74380.487
# 2                  Leh(Ladakh)                 19013.800
# 3                       Kargil                 29591.210
# ...

# %%
households=households[0:639]

# %%
households
# Out:
#      Households_Rural  Households_Urban  Households  \
# 0            158438.0           23226.0    181664.0
# 1            160649.0           27190.0    187839.0
# 2             36920.0           17474.0     54394.0
# 3             40370.0            7774.0     48144.0
# 4            132139.0           15269.0    147408.0
# ..                ...               ...         ...
# 634           87296.0          203741.0    291037.0
# 635               0.0           12110.0     12110.0
# 636           35618.0           33715.0     69333.0
# 637           15958.0               0.0     15958.0
# 638           39091.0            1094.0     40185.0
#
#                       District  Households_Rural_Livable  \
# 0                      Kupwara                 92052.478
# 1                       Badgam                 74380.487
# 2                  Leh(Ladakh)                 19013.800
# 3                       Kargil                 29591.210
# ...

# %%
households['Households_Rural_Toilet_Premise']=households['Households_Rural']*(ft['Households_Rural_Toilet_Premise']/100)
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_18032\4214470951.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   households['Households_Rural_Toilet_Premise']=households['Households_Rural']*(ft['Households_Rural_Toilet_Premise']/100)

# %%
households
# Out:
#      Households_Rural  Households_Urban  Households  \
# 0            158438.0           23226.0    181664.0
# 1            160649.0           27190.0    187839.0
# 2             36920.0           17474.0     54394.0
# 3             40370.0            7774.0     48144.0
# 4            132139.0           15269.0    147408.0
# ..                ...               ...         ...
# 634           87296.0          203741.0    291037.0
# 635               0.0           12110.0     12110.0
# 636           35618.0           33715.0     69333.0
# 637           15958.0               0.0     15958.0
# 638           39091.0            1094.0     40185.0
#
#                       District  Households_Rural_Livable  \
# 0                      Kupwara                 92052.478
# 1                       Badgam                 74380.487
# 2                  Leh(Ladakh)                 19013.800
# 3                       Kargil                 29591.210
# ...

# %%
households['Households_Urban_Livable']=households['Households_Urban']*(ft['Households_Urban_Livable']/100)
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_18032\1157591831.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   households['Households_Urban_Livable']=households['Households_Urban']*(ft['Households_Urban_Livable']/100)

# %%
households['Households_Urban_Dilapidated']=households['Households_Urban']*(ft['Households_Urban_Dilapidated']/100)
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_18032\1874085225.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   households['Households_Urban_Dilapidated']=households['Households_Urban']*(ft['Households_Urban_Dilapidated']/100)

# %%
households['Households_Urban_Toilet_Premise']=households['Households_Urban']*(ft['Households_Urban_Toilet_Premise']/100)
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_18032\1120406645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   households['Households_Urban_Toilet_Premise']=households['Households_Urban']*(ft['Households_Urban_Toilet_Premise']/100)

# %%
households
# Out:
#      Households_Rural  Households_Urban  Households  \
# 0            158438.0           23226.0    181664.0
# 1            160649.0           27190.0    187839.0
# 2             36920.0           17474.0     54394.0
# 3             40370.0            7774.0     48144.0
# 4            132139.0           15269.0    147408.0
# ..                ...               ...         ...
# 634           87296.0          203741.0    291037.0
# 635               0.0           12110.0     12110.0
# 636           35618.0           33715.0     69333.0
# 637           15958.0               0.0     15958.0
# 638           39091.0            1094.0     40185.0
#
#                       District  Households_Rural_Livable  \
# 0                      Kupwara                 92052.478
# 1                       Badgam                 74380.487
# 2                  Leh(Ladakh)                 19013.800
# 3                       Kargil                 29591.210
# ...

# %%
households = households.reindex(sorted(households.columns), axis=1)

# %%
households
# Out:
#                       District  Households  Households_Rural  \
# 0                      Kupwara    181664.0          158438.0
# 1                       Badgam    187839.0          160649.0
# 2                  Leh(Ladakh)     54394.0           36920.0
# 3                       Kargil     48144.0           40370.0
# 4                        Punch    147408.0          132139.0
# ..                         ...         ...               ...
# 634                Pondicherry    291037.0           87296.0
# 635                       Mahe     12110.0               0.0
# 636                   Karaikal     69333.0           35618.0
# 637                   Nicobars     15958.0           15958.0
# 638  North  and Middle Andaman     40185.0           39091.0
#
#      Households_Rural_Dilapidated  Households_Rural_Livable  \
# 0                       13150.354                 92052.478
# 1                        6265.311                 74380.487
# ...

# %%
households2=finalDataCopy[['Households_Rural','Households_Urban','Households','District']].copy()

# %%
households2
# Out:
#      Households_Rural  Households_Urban  Households                   District
# 0            158438.0           23226.0    181664.0                    Kupwara
# 1            160649.0           27190.0    187839.0                     Badgam
# 2             36920.0           17474.0     54394.0                Leh(Ladakh)
# 3             40370.0            7774.0     48144.0                     Kargil
# 4            132139.0           15269.0    147408.0                      Punch
# ..                ...               ...         ...                        ...
# 635               0.0           12110.0     12110.0                       Mahe
# 636           35618.0           33715.0     69333.0                   Karaikal
# 637           15958.0               0.0     15958.0                   Nicobars
# 638           39091.0            1094.0     40185.0  North  and Middle Andaman
# 639           34901.0           50631.0     85532.0              South Andaman
#
# [640 rows x 4 columns]

# %%
ft
# Out:
#                     District  Households_Rural  Households_Rural_Livable  \
# 0                    Kupwara               100                      58.1
# 1                     Badgam               100                      46.3
# 2                Leh(Ladakh)               100                      51.5
# 3                     Kargil               100                      73.3
# 4                      Punch               100                      59.5
# ..                       ...               ...                       ...
# 635                 Tiruppur               100                      27.6
# 636               Puducherry               100                      31.9
# 637                 Karaikal               100                      36.8
# 638  North  & Middle Andaman               100                      44.3
# 639            South Andaman               100                      33.5
#
#      Households_Rural_Dilapidated  Households_Rural_Toilet_Premise  \
# ...

# %%
households
# Out:
#                       District  Households  Households_Rural  \
# 0                      Kupwara    181664.0          158438.0
# 1                       Badgam    187839.0          160649.0
# 2                  Leh(Ladakh)     54394.0           36920.0
# 3                       Kargil     48144.0           40370.0
# 4                        Punch    147408.0          132139.0
# ..                         ...         ...               ...
# 634                Pondicherry    291037.0           87296.0
# 635                       Mahe     12110.0               0.0
# 636                   Karaikal     69333.0           35618.0
# 637                   Nicobars     15958.0           15958.0
# 638  North  and Middle Andaman     40185.0           39091.0
#
#      Households_Rural_Dilapidated  Households_Rural_Livable  \
# 0                       13150.354                 92052.478
# 1                        6265.311                 74380.487
# ...

# %%
households.to_csv('clean_Data/households.clean.csv')

# %%
households.head()
# Out:
#       District  Households  Households_Rural  Households_Rural_Dilapidated  \
# 0      Kupwara    181664.0          158438.0                     13150.354
# 1       Badgam    187839.0          160649.0                      6265.311
# 2  Leh(Ladakh)     54394.0           36920.0                       775.320
# 3       Kargil     48144.0           40370.0                      1412.950
# 4        Punch    147408.0          132139.0                      3171.336
#
#    Households_Rural_Livable  Households_Rural_Toilet_Premise  \
# 0                 92052.478                        77476.182
# 1                 74380.487                       133820.617
# 2                 19013.800                        32526.520
# 3                 29591.210                        39078.160
# 4                 78622.705                        18103.043
#
#    Households_Urban  Households_Urban_Dilapidated  Households_Urban_Livable  \
# ...

# %%
ds=households['District'].tolist()

# %%
#district data is in one file but not the other.

# %%
ft[~ft['District'].isin(ds)]
# Out:
#                     District  Households_Rural  Households_Rural_Livable  \
# 505     Dadra & Nagar Haveli               100                     45.50
# 590              LAKSHADWEEP               100                     40.86
# 636               Puducherry               100                     31.90
# 638  North  & Middle Andaman               100                     44.30
# 639            South Andaman               100                     33.50
#
#      Households_Rural_Dilapidated  Households_Rural_Toilet_Premise  \
# 505                          0.80                            26.50
# 590                          1.74                            98.06
# 636                          2.60                            35.80
# 638                          2.70                            48.00
# 639                          3.50                            64.70
#
#      Households_Urban  Households_Urban_Livable  Households_Urban_Dilapidated  \
# ...

# %%
households['District'].replace(['dadra & nagar haveli','puducherry','north  & middle andaman','lahul & spiti'],
                                ['dadra and nagar haveli','pondicherry','north  and middle andaman','lahul and spiti'],
                               inplace=True)

# %%
households[households['District']=='Lakshadweep']
# Out:
#         District  Households  Households_Rural  Households_Rural_Dilapidated  \
# 586  Lakshadweep     21242.0            5289.0                       195.693
#
#      Households_Rural_Livable  Households_Rural_Toilet_Premise  \
# 586                  1930.485                         3993.195
#
#      Households_Urban  Households_Urban_Dilapidated  Households_Urban_Livable  \
# 586           15953.0                       271.201                  4642.323
#
#      Households_Urban_Toilet_Premise
# 586                        14565.089

# %%
households.to_csv('clean_Data/Clean_Data/households_clean2.csv')

# %% [markdown]
# **Problem Statement 8: (Visualise the housing data)
# Visualize the following data for each state using appropriate methods:
# Number of households for 100 people
# Percentage of households that have toilet(s) in premise to the total number of households.
# Urban to rural population ratio**

# %%
toilet_premise=households["Households_Rural_Toilet_Premise"].sum()+households["Households_Urban_Toilet_Premise"].sum()

# %%
totalhouseholds=households["Households_Rural"].sum()+households["Households_Urban"].sum()

# %%
nothaving=totalhouseholds-toilet_premise
nothaving
# Out:
# 174290838.01159394

# %%
data7 = {'value': [toilet_premise,totalhouseholds]}
chart = pd.DataFrame(data7, index=['Having', 'Total households'])

# Calculate the percentage of each value
total = chart['value'].sum()
chart['percent'] = chart['value'] / total * 100

colors = ['#FFE0AC', '#FFACB7']
fig, ax = plt.subplots(figsize=(8, 6))
# Create a pie chart of the percentages
chart['percent'].plot(kind='pie', colors=colors, autopct='%1.1f%%', startangle=90, pctdistance=0.8, wedgeprops={'linewidth': 1, 'edgecolor': 'white'})
plt.axis('equal')
plt.legend(labels=chart.index, loc='upper left')
plt.title('  Percentage of households that have toilet(s) in premise to the total number of households.')

plt.legend(labels=chart.index, loc='upper right', bbox_to_anchor=(1.2, 1))
plt.tight_layout()
plt.ylabel('')

# Save the chart to a file
plt.savefig('toilet_pie_chart.png')

plt.show()

# %%
df_population = households[['Households_Urban', 'Households_Rural']]
ax = df_population.plot.bar(rot=0)
ax.set_xlabel('Population')
ax.set_ylabel('Number of People')
ax.set_title('Comparison of Urban and Rural Populations')
# Out:
# Text(0.5, 1.0, 'Comparison of Urban and Rural Populations')

# %%
df_population = households[['Households_Urban', 'Households_Rural']]

# %%
df_population
# Out:
#      Households_Urban  Households_Rural
# 0             23226.0          158438.0
# 1             27190.0          160649.0
# 2             17474.0           36920.0
# 3              7774.0           40370.0
# 4             15269.0          132139.0
# ..                ...               ...
# 634          203741.0           87296.0
# 635           12110.0               0.0
# 636           33715.0           35618.0
# 637               0.0           15958.0
# 638            1094.0           39091.0
#
# [639 rows x 2 columns]

# %%
colors = ['#FFE0AC', '#FFACB7']

# %%
df_population.plot.bar(color=colors)
plt.xlabel('Population')
plt.ylabel('Number of People')
plt.title('Comparison of Urban and Rural Populations')
plt.show()

# %%
ax = df_population.plot.bar(rot=0)
ax.set_xlabel('Population')
ax.set_ylabel('Number of People')
ax.set_title('Comparison of Urban and Rural Populations')
# Out:
# Text(0.5, 1.0, 'Comparison of Urban and Rural Populations')
