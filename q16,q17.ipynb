# %% [markdown]
# Problem Statement 16: (Gap in number of beds)
#
# Visually represent the difference between the expected number of hospital beds and the available number of hospital beds in each State/UT, as well as at the national level (if any).

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hospital=pd.read_csv('clean_Data/otherclean/hospital_clean.csv',index_col='Unnamed: 0')

# %%
hospital.head()
# Out:
#          State/UT Number of Primary Health Centers(PHCs)  \
# 29    West Bengal                                   1374
# 14    Uttarakhand                                    275
# 32  Uttar Pradesh                                   3277
# 13        Tripura                                    114
# 22      Telangana                                    788
#
#    Community Health Centers(CHCs) Sub-District/Divisional Hospitals(SDHs)  \
# 29                            406                                      70
# 14                             69                                      19
# 32                            671                                     NaN
# 13                             22                                      12
# 22                             82                                      47
#
#    District Hospitals(DHs) Hospitals  HospitalBeds  Population    Per1000
# 29                      55      1905         51163    91276115   5.605300
# ...

# %%
hospital
# Out:
#                        State/UT Number of Primary Health Centers(PHCs)  \
# 29                  West Bengal                                   1374
# 14                  Uttarakhand                                    275
# 32                Uttar Pradesh                                   3277
# 13                      Tripura                                    114
# 22                    Telangana                                    788
# 35                   Tamil Nadu                                   1854
# 3                        Sikkim                                     25
# 30                    Rajasthan                                   2463
# 18                       Punjab                                    521
# 11                  Pondicherry                                     40
# 21                       Orissa                                   1360
# 5                      Nagaland                                    134
# ...

# %%
hospital['Required']=(hospital['Population']*3)/1000

# %%
hospital['Required']
# Out:
# 29     273828.345
# 14      30258.876
# 32     599437.023
# 13      11021.751
# 22     105581.934
# 35     216441.090
# 3        1831.731
# 30     205645.311
# 18      83230.014
# 11       3743.859
# 21     125922.654
# 5        5935.506
# 6        3291.618
# 12       8900.667
# 8        8567.382
# 34     337122.999
# 26     217880.427
# 0         193.419
# 27     100218.183
# 31     183420.915
# 15      98964.402
# 17      36801.039
# 16      20593.806
# 19      76054.386
# 28     181319.076
# 9        4375.635
# 25      50363.823
# 1         729.741
# 2        1031.127
# 20      76635.594
# 10       3166.350
# 23     312298.356
# 24      93616.728
# 7        4151.181
# 33     148160.397
# 4        1141.743
# 36    3632699.955
# Name: Required, dtype: float64

# %%
hospital[hospital['Per1000']<3.0]
# Out:
#          State/UT Number of Primary Health Centers(PHCs)  \
# 32  Uttar Pradesh                                   3277
# 15      Jharkhand                                    343
# 23          Bihar                                   2007
#
#    Community Health Centers(CHCs) Sub-District/Divisional Hospitals(SDHs)  \
# 32                            671                                     NaN
# 15                            179                                      13
# 23                             63                                      33
#
#    District Hospitals(DHs) Hospitals  HospitalBeds  Population   Per1000  \
# 32                     174      4122         58310   199812341  2.918238
# 15                      23       558          7404    32988134  2.244443
# 23                      43      2146         17796   104099452  1.709519
#
#       Required
# 32  599437.023
# 15   98964.402
# 23  312298.356

# %%
hospital
# Out:
#                        State/UT Number of Primary Health Centers(PHCs)  \
# 29                  West Bengal                                   1374
# 14                  Uttarakhand                                    275
# 32                Uttar Pradesh                                   3277
# 13                      Tripura                                    114
# 22                    Telangana                                    788
# 35                   Tamil Nadu                                   1854
# 3                        Sikkim                                     25
# 30                    Rajasthan                                   2463
# 18                       Punjab                                    521
# 11                  Pondicherry                                     40
# 21                       Orissa                                   1360
# 5                      Nagaland                                    134
# ...

# %%
onlystates=hospital.iloc[0:36]

# %%
onlystates.to_csv('clean_Data/otherclean/statesCleanq16.csv')

# %%
onlystates.sort_values('Required',ascending=False)
# Out:
#                        State/UT Number of Primary Health Centers(PHCs)  \
# 32                Uttar Pradesh                                   3277
# 34                  Maharashtra                                   2638
# 23                        Bihar                                   2007
# 29                  West Bengal                                   1374
# 26               Madhya Pradesh                                   1420
# 35                   Tamil Nadu                                   1854
# 30                    Rajasthan                                   2463
# 31                    Karnataka                                   2547
# 28                      Gujarat                                   1770
# 33               Andhra Pradesh                                   1417
# 21                       Orissa                                   1360
# 22                    Telangana                                    788
# ...

# %%
states=onlystates['State/UT'].tolist()

# %%
states
# Out:
# ['West Bengal',
#  'Uttarakhand',
#  'Uttar Pradesh',
#  'Tripura',
#  'Telangana',
#  'Tamil Nadu',
#  'Sikkim',
#  'Rajasthan',
#  'Punjab',
#  'Pondicherry',
#  'Orissa',
#  'Nagaland',
#  'Mizoram',
#  'Meghalaya',
#  'Manipur',
#  'Maharashtra',
#  'Madhya Pradesh',
#  'Lakshadweep',
#  'Kerala',
#  'Karnataka',
#  'Jharkhand',
#  'Jammu and Kashmir',
#  'Himachal Pradesh',
#  'Haryana',
#  'Gujarat',
#  'Goa',
#  'Delhi',
#  'Daman and Diu',
#  'Dadra and Nagar Haveli',
#  'Chhattisgarh',
#  'Chandigarh',
#  'Bihar',
#  'Assam',
#  'Arunachal Pradesh',
#  'Andhra Pradesh',
#  'Andaman and Nicobar Islands']

# %%
presentBeds=onlystates['HospitalBeds'].tolist()

# %%
RequiredBeds=onlystates['Required'].tolist()

# %%
pb=hospital['HospitalBeds'].tolist()

# %%
rb=hospital['Required'].tolist()

# %% [markdown]
# https://www.geeksforgeeks.org/plotting-multiple-bar-charts-using-matplotlib-in-python/

# %%
X_axis = np.arange(len(states))
plt.figure(figsize=(20,15))
plt.bar(X_axis - 0.2, presentBeds, 0.4, label = 'available',color='#FFE0AC')
plt.bar(X_axis + 0.2, RequiredBeds, 0.4, label = 'expected',color='#FFACB7')
plt.xticks(X_axis, states,rotation=90)
plt.yticks(np.arange(round(min(RequiredBeds)),round(max(RequiredBeds)),50000))
plt.xlabel("States")
plt.ylabel("Beds")
plt.title("Required vs available beds in India")
plt.legend(loc=0)
plt.savefig('expectedbeds_chart.png')
plt.show()

# %%
np.arange(round(min(RequiredBeds)),round(max(RequiredBeds)),100000)
# Out:
# array([   193, 100193, 200193, 300193, 400193, 500193])

# %%
max(RequiredBeds)
# Out:
# 599437.023

# %%
plt.savefig('AvailableVsRequired.jpg')

# %%
sts=hospital['State/UT'].tolist()

# %%
X_axis = np.arange(len(sts))
plt.figure(figsize=(18,9))
plt.bar(X_axis - 0.2, pb, 0.4, label = 'available',color='#FFE0AC')
plt.bar(X_axis + 0.2, rb, 0.4, label = 'expected',color='#FFACB7')
plt.xticks(X_axis, sts,rotation=90)
plt.yticks(np.arange(round(min(pb)),round(max(rb)),100000))
plt.xlabel("States")
plt.ylabel("Beds")
plt.title("Required vs available beds in India")
plt.legend(loc=0)
plt.show()

# %% [markdown]
# In a hypothetical situation if the government wishes to fill the gap between the available facility and the WHO standards all by itself how many government hospitals may be required in each state or union territory as well as at the national level?
# Find the average number of beds in a government hospital. Divide it by the gap in the number of beds to reach the standards in the region, and round the number to the nearest integer to find the value.
# Represent the findings visually.

# %%
government_hospitalsavg=hospital['HospitalBeds'].tolist()

# %%
government_hospitalsavg=sum(government_hospitalsavg)/len(government_hospitalsavg)

# %%
government_hospitalsavg
# Out:
# 39947.24324324324

# %%
hospital['gap']=hospital['Required']-hospital['HospitalBeds']

# %%
hospital=hospital[0:36]

# %%
hospital.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 36 entries, 29 to 4
# Data columns (total 11 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   State/UT                                 36 non-null     object
#  1   Number of Primary Health Centers(PHCs)   36 non-null     object
#  2   Community Health Centers(CHCs)           36 non-null     object
#  3   Sub-District/Divisional Hospitals(SDHs)  29 non-null     object
#  4   District Hospitals(DHs)                  36 non-null     object
#  5   Hospitals                                36 non-null     object
#  6   HospitalBeds                             36 non-null     int64
#  7   Population                               36 non-null     int64
#  8   Per1000                                  36 non-null     float64
#  9   Required                                 36 non-null     float64
# ...

# %%
hospital['Hospitals']=hospital['Hospitals'].astype('int64')
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_13212\732218686.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital['Hospitals']=hospital['Hospitals'].astype('int64')

# %%
hospital[['HospitalBeds','Hospitals']]
# Out:
#     HospitalBeds  Hospitals
# 29         51163       1905
# 14          6660        383
# 32         58310       4122
# 13          4895        157
# 22         17358        932
# 35         72616       2581
# 3           1145         32
# 30         51844       3139
# 18         13527        742
# 11          4462         53
# 21         16497       1799
# 5           1944        166
# 6           2312         87
# 12          4585        180
# 8           2562        114
# 34         68998       3239
# 26         38140       1867
# 0            250         10
# 27         39511       1297
# 31         56333       2943
# 15          7404        558
# 17         11342        818
# 16          8706        671
# 19         13841        683
# 28         41129       2236
# 9           2666         40
# 25         20572        615
# 1            298          8
# 2            568         13
# 20         14354       1023
# 10          3756         47
# 23         17796       2146
# ...

# %%
hospital['bedsperhospital']=hospital['HospitalBeds']/hospital['Hospitals']
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_13212\2010356472.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital['bedsperhospital']=hospital['HospitalBeds']/hospital['Hospitals']

# %%
hospital.head()
# Out:
#          State/UT Number of Primary Health Centers(PHCs)  \
# 29    West Bengal                                   1374
# 14    Uttarakhand                                    275
# 32  Uttar Pradesh                                   3277
# 13        Tripura                                    114
# 22      Telangana                                    788
#
#    Community Health Centers(CHCs) Sub-District/Divisional Hospitals(SDHs)  \
# 29                            406                                      70
# 14                             69                                      19
# 32                            671                                     NaN
# 13                             22                                      12
# 22                             82                                      47
#
#    District Hospitals(DHs)  Hospitals  HospitalBeds  Population    Per1000  \
# 29                      55       1905         51163    91276115   5.605300
# ...

# %%
hospital.rename(columns={'Per1000':'bedsper10k','bedsperhospital':'avg beds'},inplace=True)
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_13212\3400243962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital.rename(columns={'Per1000':'bedsper10k','bedsperhospital':'avg beds'},inplace=True)

# %%
hospital['new hospitals']=round(hospital['gap']/hospital['avg beds'])
# Out:
# C:\Users\miles.MILE-BL-4748-LA.000\AppData\Local\Temp\ipykernel_13212\1271257486.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   hospital['new hospitals']=round(hospital['gap']/hospital['avg beds'])

# %%
 hospital.head()
# Out:
#          State/UT Number of Primary Health Centers(PHCs)  \
# 29    West Bengal                                   1374
# 14    Uttarakhand                                    275
# 32  Uttar Pradesh                                   3277
# 13        Tripura                                    114
# 22      Telangana                                    788
#
#    Community Health Centers(CHCs) Sub-District/Divisional Hospitals(SDHs)  \
# 29                            406                                      70
# 14                             69                                      19
# 32                            671                                     NaN
# 13                             22                                      12
# 22                             82                                      47
#
#    District Hospitals(DHs)  Hospitals  HospitalBeds  Population  bedsper10k  \
# 29                      55       1905         51163    91276115    5.605300
# ...

# %%
hospital.sort_values(by='new hospitals',ascending=False)
# Out:
#                        State/UT Number of Primary Health Centers(PHCs)  \
# 32                Uttar Pradesh                                   3277
# 23                        Bihar                                   2007
# 34                  Maharashtra                                   2638
# 21                       Orissa                                   1360
# 30                    Rajasthan                                   2463
# 26               Madhya Pradesh                                   1420
# 29                  West Bengal                                   1374
# 28                      Gujarat                                   1770
# 15                    Jharkhand                                    343
# 31                    Karnataka                                   2547
# 35                   Tamil Nadu                                   1854
# 24                        Assam                                   1007
# ...

# %%
hospital.to_csv('clean_Data/otherclean/hospitalq17.csv')

# %%
x = hospital['State/UT'].tolist()
y1 = hospital['Hospitals'].tolist()
y2 = hospital['new hospitals'].tolist()
plt.title('Gap or average of beds')
plt.bar(x, y2, bottom=y1,color='#FFACB7')
plt.bar(x, y1, color='#FFE0AC')
plt.legend(['Required/Gap','Present'],loc=0)
plt.xticks(rotation=90)
plt.show()
